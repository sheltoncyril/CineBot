# %% [markdown]
# ## Baseline Movie Recomender System

# %%
import pandas as pd
import numpy as np
from transformers import BertTokenizer, BertModel
import torch

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("Data/IMDB top 1000.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                              Title Certificate  \
# 0           0                 1. The Shawshank Redemption (1994)           R
# 1           1                            2. The Godfather (1972)           R
# 2           2                          3. The Dark Knight (2008)       PG-13
# 3           3                   4. The Godfather: Part II (1974)           R
# 4           4  5. The Lord of the Rings: The Return of the Ki...       PG-13
#
#   Duration                     Genre  Rate  Metascore  \
# 0  142 min                     Drama   9.3       80.0
# 1  175 min              Crime, Drama   9.2      100.0
# 2  152 min      Action, Crime, Drama   9.0       84.0
# 3  202 min              Crime, Drama   9.0       90.0
# 4  201 min  Action, Adventure, Drama   8.9       94.0
#
#                                          Description  \
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# 2  When the menace known as the Joker wreaks havo...
# 3  The early life and career of Vito Corleone in ...
# 4  Gandalf and Aragorn lead the World of Men agai...
#
#                                                 Cast  \
# 0  Director: Frank Darabont | Stars: Tim Robbins,...
# 1  Director: Francis Ford Coppola | Stars: Marlon...
# 2  Director: Christopher Nolan | Stars: Christian...
# 3  Director: Francis Ford Coppola | Stars: Al Pac...
# 4  Director: Peter Jackson | Stars: Elijah Wood, ...
#
#                                  Info
# 0   Votes: 2,295,987 | Gross: $28.34M
# 1  Votes: 1,584,782 | Gross: $134.97M
# 2  Votes: 2,260,649 | Gross: $534.86M
# 3   Votes: 1,107,253 | Gross: $57.30M
# 4  Votes: 1,614,369 | Gross: $377.85M

# %%
df.shape
# Out:
# (1000, 10)

# %%
plots = df['Description'].values.tolist()
for i in range(len(plots)):
    plots[i] = plots[i] + " " +df.loc[i,'Genre'] + " " + df.loc[i,'Cast']

# %% [markdown]
# ## TF IDF recomender

# %%
df[df['Cast'].str.contains('Leonardo DiCaprio') ]
# Out:
#      Unnamed: 0                                Title Certificate Duration  \
# 8             8                  9. Inception (2010)       PG-13  148 min
# 36           36              37. The Departed (2006)           R  151 min
# 61           61          62. Django Unchained (2012)           R  165 min
# 144         144           145. Shutter Island (2010)           R  138 min
# 146         146  147. The Wolf of Wall Street (2013)           R  180 min
# 239         239      242. Catch Me If You Can (2002)       PG-13  141 min
# 339         339             342. The Revenant (2015)           R  156 min
# 356         356            359. Blood Diamond (2006)           R  143 min
# 439         439             342. The Revenant (2015)           R  156 min
# 456         456            359. Blood Diamond (2006)           R  143 min
# 539         539             342. The Revenant (2015)           R  156 min
# 556         556            359. Blood Diamond (2006)           R  143 min
# 639         639             342. The Revenant (2015)           R  156 min
# 656         656            359. Blood Diamond (2006)           R  143 min
# 739         739             342. The Revenant (2015)           R  156 min
# 756         756            359. Blood Diamond (2006)           R  143 min
# 839         839             342. The Revenant (2015)           R  156 min
# 856         856            359. Blood Diamond (2006)           R  143 min
# 939         939             342. The Revenant (2015)           R  156 min
# 956         956            359. Blood Diamond (2006)           R  143 min
#
#                           Genre  Rate  Metascore  \
# 8     Action, Adventure, Sci-Fi   8.8       74.0
# 36       Crime, Drama, Thriller   8.5       85.0
# 61               Drama, Western   8.4       81.0
# 144           Mystery, Thriller   8.2       63.0
# 146     Biography, Crime, Drama   8.2       75.0
# 239     Biography, Crime, Drama   8.1       75.0
# 339    Action, Adventure, Drama   8.0       76.0
# 356  Adventure, Drama, Thriller   8.0       64.0
# 439    Action, Adventure, Drama   8.0       76.0
# 456  Adventure, Drama, Thriller   8.0       64.0
# 539    Action, Adventure, Drama   8.0       76.0
# 556  Adventure, Drama, Thriller   8.0       64.0
# 639    Action, Adventure, Drama   8.0       76.0
# 656  Adventure, Drama, Thriller   8.0       64.0
# 739    Action, Adventure, Drama   8.0       76.0
# 756  Adventure, Drama, Thriller   8.0       64.0
# 839    Action, Adventure, Drama   8.0       76.0
# 856  Adventure, Drama, Thriller   8.0       64.0
# 939    Action, Adventure, Drama   8.0       76.0
# 956  Adventure, Drama, Thriller   8.0       64.0
#
#                                            Description  \
# 8    A thief who steals corporate secrets through t...
# 36   An undercover cop and a mole in the police att...
# 61   With the help of a German bounty hunter, a fre...
# 144  In 1954, a U.S. Marshal investigates the disap...
# 146  Based on the true story of Jordan Belfort, fro...
# 239  A seasoned FBI agent pursues Frank Abagnale Jr...
# 339  A frontiersman on a fur trading expedition in ...
# 356  A fisherman, a smuggler, and a syndicate of bu...
# 439  A frontiersman on a fur trading expedition in ...
# 456  A fisherman, a smuggler, and a syndicate of bu...
# 539  A frontiersman on a fur trading expedition in ...
# 556  A fisherman, a smuggler, and a syndicate of bu...
# 639  A frontiersman on a fur trading expedition in ...
# 656  A fisherman, a smuggler, and a syndicate of bu...
# 739  A frontiersman on a fur trading expedition in ...
# 756  A fisherman, a smuggler, and a syndicate of bu...
# 839  A frontiersman on a fur trading expedition in ...
# 856  A fisherman, a smuggler, and a syndicate of bu...
# 939  A frontiersman on a fur trading expedition in ...
# 956  A fisherman, a smuggler, and a syndicate of bu...
#
#                                                   Cast  \
# 8    Director: Christopher Nolan | Stars: Leonardo ...
# 36   Director: Martin Scorsese | Stars: Leonardo Di...
# 61   Director: Quentin Tarantino | Stars: Jamie Fox...
# 144  Director: Martin Scorsese | Stars: Leonardo Di...
# 146  Director: Martin Scorsese | Stars: Leonardo Di...
# 239  Director: Steven Spielberg | Stars: Leonardo D...
# 339  Director: Alejandro G. Iñárritu | Stars: Leona...
# 356  Director: Edward Zwick | Stars: Leonardo DiCap...
# 439  Director: Alejandro G. Iñárritu | Stars: Leona...
# 456  Director: Edward Zwick | Stars: Leonardo DiCap...
# 539  Director: Alejandro G. Iñárritu | Stars: Leona...
# 556  Director: Edward Zwick | Stars: Leonardo DiCap...
# 639  Director: Alejandro G. Iñárritu | Stars: Leona...
# 656  Director: Edward Zwick | Stars: Leonardo DiCap...
# 739  Director: Alejandro G. Iñárritu | Stars: Leona...
# 756  Director: Edward Zwick | Stars: Leonardo DiCap...
# 839  Director: Alejandro G. Iñárritu | Stars: Leona...
# 856  Director: Edward Zwick | Stars: Leonardo DiCap...
# 939  Director: Alejandro G. Iñárritu | Stars: Leona...
# 956  Director: Edward Zwick | Stars: Leonardo DiCap...
#
#                                    Info
# 8    Votes: 2,022,655 | Gross: $292.58M
# 36   Votes: 1,167,751 | Gross: $132.38M
# 61   Votes: 1,328,656 | Gross: $162.81M
# 144  Votes: 1,105,456 | Gross: $128.01M
# 146  Votes: 1,152,702 | Gross: $116.90M
# 239    Votes: 808,593 | Gross: $164.62M
# 339    Votes: 690,094 | Gross: $183.64M
# 356     Votes: 492,148 | Gross: $57.37M
# 439    Votes: 690,094 | Gross: $183.64M
# 456     Votes: 492,148 | Gross: $57.37M
# 539    Votes: 690,094 | Gross: $183.64M
# 556     Votes: 492,148 | Gross: $57.37M
# 639    Votes: 690,094 | Gross: $183.64M
# 656     Votes: 492,148 | Gross: $57.37M
# 739    Votes: 690,094 | Gross: $183.64M
# 756     Votes: 492,148 | Gross: $57.37M
# 839    Votes: 690,094 | Gross: $183.64M
# 856     Votes: 492,148 | Gross: $57.37M
# 939    Votes: 690,094 | Gross: $183.64M
# 956     Votes: 492,148 | Gross: $57.37M

# %%
# Initialize TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer(use_idf=False)

# Fit the vectorizer to the documents and transform them into TF-IDF vectors
tfidf = tfidf_vectorizer.fit_transform(plots)

# %%
query = ["Action with Leonardo DiCaprio"]

tfidf_query = tfidf_vectorizer.transform(query)

cos_similarities = cosine_similarity(tfidf_query,tfidf)
idx = np.argmax(cos_similarities)
df.loc[idx]['Title'],plots[idx],cos_similarities[:,idx]
# Out:
# ('62. Django Unchained (2012)',
#  'With the help of a German bounty hunter, a freed slave sets out to rescue his wife from a brutal Mississippi plantation owner. Drama, Western Director: Quentin Tarantino | Stars: Jamie Foxx, Christoph Waltz, Leonardo DiCaprio, Kerry Washington',
#  array([0.25724788]))

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# %%
tokens = tokenizer(plots, padding=True, truncation=True, return_tensors='pt')

# %%
with torch.no_grad():
    outputs = model(**tokens)

embeddings = outputs.pooler_output

# %%
query = ["Action movie with horror "]
query_token = tokenizer(query, padding=True, truncation=True, return_tensors='pt')

with torch.no_grad():
    outputs = model(**query_token)

embedding_query = outputs.pooler_output
# Calculate cosine similarity between query and all descriptions
cos_similarities = cosine_similarity(embedding_query,embeddings)



idx = np.argmax(cos_similarities)

# %%
df.loc[idx]['Title'],plots[idx]
# Out:
# ('297. The 400 Blows (1959)',
#  'A young boy, left without attention, delves into a life of petty crime. Crime, Drama')
